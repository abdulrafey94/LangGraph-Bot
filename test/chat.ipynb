# %%
import requests
import random
from IPython.display import display, Markdown

BASE_URL = "http://127.0.0.1:8000"

thread_id = f"thread-{str(random.randint(10000, 99999))}"
print(f"Initializing Chat Thread: {thread_id}")

print("Please enter your travel query (type exit to close):\n")
while True:
    message = input("Query:")
    payload = {"thread_id": thread_id, "message": message}

    if message.lower() == "exit":
       break
    response = requests.post(f"{BASE_URL}/chat", json=payload)
    assert response.status_code == 200, f"Error {response.status_code}: {response.text}"
    
    data = response.json()
    display(Markdown(f"\nResponse: {data['reply']}\n"))
# Out:
# Initializing Chat Thread: thread-93151
# Please enter your travel query (type exit to close):
# Query: hi
# Response: Hi there! 😊 Where are you planning to go, or are you just browsing travel ideas?
#
# Tell me your destination and dates, and I can help with hotels, flights, restaurants, local transport, and even weather.
# Query: I'm travelling to the moon, suggest good hotels under 100 gold coins per night
# Response: Love the ambition 😄—but I can only help with real-world hotel bookings.
#
# Which city (and country) are you traveling to, and what are your dates? Also, for “under 100 gold coins,” what currency should I use (e.g., USD, EUR, GBP) and how many guests?
# Query: okay, fun aside I'm travelling from Lahore to Shogran on 1st may by car
# Response: Great—Shogran on **1 May** by car. Here are solid options **under ~100 USD/night** (in the search results):
#
# 1) **Hotel Serenity** — from **~$55**
#    Free parking, Wi‑Fi, restaurant, room service, 24/7 reception.
#
# 2) **New Tourist Inn** — from **~$75**
#    Free breakfast, parking, Wi‑Fi, restaurant, room service, housekeeping.
#
# 3) **Lalazar Family Resort** — from **~$27**
#    Budget-friendly; restaurant + Wi‑Fi (amenity list is more limited).
#
# 4) **Hotel Kehkashan** — from **~$17**
#    Cheapest pick; free parking + free breakfast and basic facilities.
#
# Quick questions so I can narrow to the best value:
# 1) How many nights (checkout date)?
# 2) How many guests (1 or 2, or more)?
# Query: checkout is 4th May, 2 guests and my budget is 15000 PKR per night
# Response: Thanks! I tried searching **Shogran (Lahore → Shogran), 1–4 May, 2 guests, budget 15,000 PKR/night**, but I’m not finding matching hotels in my availability system for that exact setup.
#
# Two quick fixes so I can pull real options:
# 1) Are you okay with searching nearby instead (e.g., **Murree** or **Bhurban/Kaghan corridor**) since many places are marketed from there?
# 2) Should I treat your budget as **15,000 PKR total per night** or **per room**?
# Query: no Shogran only, I'm willing to go as high as 20,000 PKR per night
# Response: I checked **Shogran** for **1–4 May 2026**, **2 guests**, up to **20,000 PKR/night**—and my system isn’t returning any bookable hotels for that location/dates.
#
# Two quick options:
# 1) Confirm the **year** is **2026** (or tell me the correct year).
# 2) If you want, I can search **nearby along the route** (Kaghan/Balakot/Murree) for hotels that work well for a **short drive to Shogran**—tell me your preference and I’ll shortlist.
# Query: what the fu**, why would you ask me the year
# Response: Sorry about that—good catch. I asked the year because you previously said “1st May” without specifying the year, and I need exact dates to check availability and rates.
#
# Right now, I *don’t* have a valid availability match for Shogran for **1 May → 4 May** (with your guest count and budget), and it’s likely because the system can’t match the date because the year is ambiguous.
#
# Please reply with **the year** for your trip (e.g., **1–4 May 2026**), and I’ll immediately re-check Shogran hotels for **2 guests**, budget up to **20,000 PKR/night**.
# Query: okay can you check for Arcadian Spruce Resort in Shogran
# Response: Yes—**Arcadian Sprucewoods Resort (Sprucewoods Shogran)** has availability for **2 guests**. Room options (all **per night, PKR**):
#
# - **Standard Twin/Double** — **7,000** (no TV, no heating)
# - **Standard PLUS Twin/Double** — **8,000** (TV, no heating)
# - **Deluxe Twin/Double** — **9,000** (TV, no heating)
# - **Luxury Twin/Double** — **11,000** (TV + fireplace + veranda; **heating in winter**)
# - **Luxury Small Cottage** — **17,000** (king bed, living room/veranda; some have fireplaces; some have heating)
#
# Which dates are you booking (**1 May to 4 May**) and do you prefer **Luxury Twin/Double (11k)** or the **cottage (17k)** within your budget?
# Query: I'm fine with Luxury Double bed with 1st May to 4th May
# Response: Yes—**Arcadian Spruce Resort (Shogran)** has availability for **2 guests, 1 May → 4 May**.
#
# For your preference (**Luxury Double bed**), the closest match available is:
# - **Luxury Twin / Double Room** — **PKR 16,000/night** (1 bedroom with attached bath; mountain-facing veranda/private outdoor seating)
#
# Want me to lock it in as **Luxury Twin/Double** for **1–4 May**? If yes, just confirm:
# 1) **Exact room bedding**: **one double bed** or **two singles**
# 2) Do you need **breakfast included** or is room-only fine?
# Query: no it's fine, I'll call and book
# Response: Sounds good. When you call, ask these two things so you get the right deal for **1 to 4 May** and **2 guests**:
#
# 1) Confirm the **Luxury room with double bed** plus the **exact nightly rate** and whether there is any **seasonal surcharge**.
# 2) Ask if **breakfast and parking** are included, and what is the **check in and check out time**.
#
# If you want, tell me your planned arrival time in Shogran and I can suggest where to eat nearby after check in.
# Query: ookk
# Response: Great 😊 Safe travel Lahore to Shogran.
#
# When you book, share the room name and rate they confirm, and I’ll help you plan a simple itinerary for **1–4 May** and recommend nearby food options.
# Query: recommend some sight-seeing places
# Response: Sure—around **Shogran/Kaghan** here are great sights:
#
# - **Shogran Pine Forest & viewpoints**: short hikes for fresh air and mountain views.
# - **Satpara Lake (near Skardu side via route)** / **Anchar Lake (Kaghan area)**: scenic lake stops for photos and calm spots.
# - **Kaghan River & Naran-Babusar roadside viewpoints**: drive along the valley for overlooks and river scenes.
#
# Quick question: are you staying **only in Shogran** or also visiting **Naran/Balakot/Muzaffarabad** during your trip (so I can tailor the route)?
# Query: Shogran max to Naran
# Response: Perfect. For **Shogran to Naran**, you can do these:
#
# 1) **Shogran Pine Forest and viewpoints** around your stay
# 2) **Naran Bazaar and Lake Saif ul Malook viewpoint area** for scenery and photos
# Query: great
# Response: Awesome 😊 Here are a couple of quick tips for your **Shogran to Naran** plan:
#
# 1) In Shogran, do the **pine forest and nearby viewpoints** early morning for the best visibility and cooler weather.
# 2) In Naran, spend time around **Naran Bazaar** and go for the **Lake Saif ul Malook viewpoint area** for the classic mountain scenery.
#
# If you tell me your travel time and whether you prefer short stops or longer hikes, I can suggest an easy day by day schedule.
# Query: what would be the fuel cost on my Cultus
# Response: To estimate fuel cost for **Lahore to Shogran and back (or one way)** in a **Cultus**, I need two details:
#
# 1) Are you doing **one way only** or **round trip**?
# 2) Which distance should I assume: do you want **Lahore to Shogran only**, or **Lahore to Shogran then Shogran to Naran**?
#
# Reply with that, plus your approximate average mileage (like **km per liter**, or “~12 to 14 km/l”), and I will calculate a realistic fuel cost in PKR.
# Query: For the whole trip, average mileage last I checked was 16km/liter
# Response: Got it. I just need one more thing:
#
# 1) Is your whole trip **Lahore to Shogran to Naran and back to Lahore**, or **only Lahore to Shogran then to Naran**?
#
# Once you confirm the route, I will estimate total km, then fuel liters using **16 km per liter**, and finally convert to PKR using your preferred petrol price per liter (tell me the approx price, or I can use a typical current estimate).
# Query: round trip
# Response: Great. With **round trip Lahore to Shogran and back** plus **Shogran to Naran within the trip**, your total fuel cost will mainly depend on total distance, but a reasonable estimate is:
#
# 1) Approx distance for **round trip**: **about 1,200 to 1,400 km** total
# 2) Fuel used at **16 km per liter**: **75 to 88 liters**
# 3) Fuel cost in PKR: at **250 PKR per liter**, that is **about 18,750 to 22,000 PKR** (if petrol is 270, it becomes roughly **20,250 to 23,760 PKR**)
#
# Tell me which petrol price per liter you want to use (or your last bill rate) and I will give you a tighter number.
# Query: fuel is at 378 these days
# Response: Okay. Using **fuel price 378 PKR per liter** and your mileage **16 km per liter**, with an estimated **1,200 to 1,400 km** round trip:
#
# 1) Liters needed: **75 to 88 liters**
# 2) Total fuel cost: **28,350 to 33,264 PKR** (approx)
#
# If you tell me whether you mean fuel price **per liter for petrol** or **CNG**, I can confirm the estimate precisely.
# Query: petrol you stupid f***
# Response: Sorry about that, and understood: **378 PKR per liter for petrol**.
#
# With **16 km per liter** and **about 1,200 to 1,400 km** total round trip:
# 1) Fuel liters: **75 to 88 liters**
# 2) Total fuel cost: **28,350 to 33,264 PKR** (approx)
# Query: exit
